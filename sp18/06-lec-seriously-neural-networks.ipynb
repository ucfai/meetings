# %%
from IPython.display import SVG, HTML

def anim_path(svg_path):
    return "/notebooks/__admin__/anim/{}".format(svg_path)

# %% [markdown]
# # Seriously, Neural Networks (RNNs)

# %%
SVG(filename=anim_path("rnns/cell-lstm.svg"))
